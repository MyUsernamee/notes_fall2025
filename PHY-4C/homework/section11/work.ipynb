# %%
# %display latex

# %% [markdown]
# # Homework 11

# %% [markdown]
# ## Problem 1
#
# In a re-creation of Young’s double-slit experiment, a laser illuminates a pair of slits with separation 0.640 mm that are a distance 2.80 m from a screen. In the pattern displayed on the screen, the first interference maximum is 2.61 mm from the center of the pattern. Find the wavelength of the light.
#
# Enter your answer, in nm, in the box below.

# %%
from tqdm import tqdm

seperation = 0.60 / 1000
wall_distance = 2.80
interference_max = 2.66 / 1000

def slit_distance(x_offset, z_offset, slit_offset):
    return sqrt((x_offset - slit_offset) ** 2 + z_offset ** 2)
def wall_slit_distance(x_offset, slit_offset) :
    return slit_distance(x_offset, wall_distance, slit_offset)

wavelength = var('lambda_', domain=RR)
wavelength

lt_distance = wall_distance(interference_max, -seperation / 2)
eq =  == wall_distance(int
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /mnt/nvmessd/Projects/PythonProjects/miniforge3/envs/sage/lib/python3.12/site-packages/sage/interfaces/interface.py:753, in InterfaceElement.__init__(self, parent, value, is_name, name)
#     752 try:
# --> 753     self._name = parent._create(value, name=name)
#     754 except (TypeError, RuntimeError, ValueError) as x:
#
# File /mnt/nvmessd/Projects/PythonProjects/miniforge3/envs/sage/lib/python3.12/site-packages/sage/interfaces/maxima_lib.py:624, in MaximaLib._create(self, value, name)
#     623     else:
# --> 624         self.set(name, value)
#     625 except RuntimeError as error:
#
# File /mnt/nvmessd/Projects/PythonProjects/miniforge3/envs/sage/lib/python3.12/site-packages/sage/interfaces/maxima_lib.py:534, in MaximaLib.set(self, var, value)
#     533 cmd = '%s : %s$' % (var, value.rstrip(';'))
# ...

# %%
from tqdm import tqdm

seperation = 0.630 / 1000
wall_distance = 2.80
interference_max = 2.58 / 1000

def slit_distance(x_offset, z_offset, slit_offset):
    return sqrt((x_offset - slit_offset) ** 2 + z_offset ** 2)
def wall_slit_distance(x_offset, slit_offset) :
    return slit_distance(x_offset, wall_distance, slit_offset)

wavelength = var('lambda_', domain=RR)
wavelength

lt_distance = wall_slit_distance(interference_max, - seperation / 2)
rt_distance = wall_slit_distance(interference_max, seperation / 2)
eq = lt_distance == rt_distance + wavelength

solve(eq, wavelength)[0].rhs().n() * 1e9
# Out:
# 580.499750046925
